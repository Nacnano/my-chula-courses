# %% [markdown]
# # Setup

# %%
# !pip install -qU langchain
# !pip install -qU langchain-google-genai
# !pip install -qU langchain-huggingface
# !pip install -qU langchain-qdrant
# !pip install -qU langchain-community
# !pip install -qU langgraph
# !pip install fastembed
# !pip install datasets
# !pip install -U "fsspec[http]==2024.10.0"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.3/423.3 kB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 65.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.17 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.7/306.7 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 19.5 MB/s eta 0:00:00
# Collecting fastembed
#   Downloading fastembed-0.6.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /usr/local/lib/python3.11/dist-packages (from fastembed) (0.30.1)
# Collecting loguru<0.8.0,>=0.7.2 (from fastembed)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting mmh3<6.0.0,>=4.1.0 (from fastembed)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from fastembed) (2.0.2)
# Collecting onnxruntime!=1.20.0,>=1.17.0 (from fastembed)
#   Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: pillow<12.0.0,>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from fastembed) (11.1.0)
# Collecting py-rust-stemmers<0.2.0,>=0.1.0 (from fastembed)
#   Downloading py_rust_stemmers-0.1.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.11/dist-packages (from fastembed) (2.32.3)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from fastembed) (0.21.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.11/dist-packages (from fastembed) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (4.13.0)
# Collecting coloredlogs (from onnxruntime!=1.20.0,>=1.17.0->fastembed)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (2025.1.31)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.3.0)
# Downloading fastembed-0.6.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.8 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.4 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 82.9 MB/s eta 0:00:00
# Downloading py_rust_stemmers-0.1.5-cp311-cp311-manylinux_2_28_x86_64.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.8/324.8 kB 28.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.6 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: py-rust-stemmers, mmh3, loguru, humanfriendly, coloredlogs, onnxruntime, fastembed
# Successfully installed coloredlogs-15.0.1 fastembed-0.6.0 humanfriendly-10.0 loguru-0.7.3 mmh3-5.1.0 onnxruntime-1.21.0 py-rust-stemmers-0.1.5
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 32.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.8 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 18.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.6 MB/s eta 0:00:00
# Installing collected packages: fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16

# %% [markdown]
# # Code

# %% [markdown]
# In this assignment, you will need to set up and use
# 1. LangSmith to monitor your agent.
# 2. Use hybrid search to improve your retriever
# 3. Use a reranker to improve your search result.

# %% [markdown]
# ## TODO 0: Set up LangSmith
#
# Create a LangSmith account and set up tracing for this assignment. https://www.smith.langchain.com/.
#
# No need to configure, just add your LangSmith API key.

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = userdata.get('LANGCHAIN_API_KEY')

# %% [markdown]
# ## Components

# %% [markdown]
# We will be using Gemini as our LLM. Feel free to try out others if you want.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-001")

# %% [markdown]
# For our sentence embeddings, we will use [ModernBERT](https://arxiv.org/abs/2412.13663) trained by Alibaba as it is small and performant.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

model_kwargs = {'trust_remote_code': True}
embeddings = HuggingFaceEmbeddings(model_name="Alibaba-NLP/gte-modernbert-base",model_kwargs=model_kwargs)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/298M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.58M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %% [markdown]
# Likewise, the reranker is also based on the ModernBERT trained by Alibaba.

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder

model = HuggingFaceCrossEncoder(model_name="Alibaba-NLP/gte-reranker-modernbert-base")
# Out:
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/598M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.58M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]

# %% [markdown]
# For our dataset, we will be using SQuAD v2 dataset.

# %%
import datasets

ds = datasets.load_dataset("rajpurkar/squad_v2", split="validation")
# Out:
# README.md:   0%|          | 0.00/8.92k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/16.4M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %% [markdown]
# ## Indexing

# %%
from langchain_core.documents import Document

# %%
all_docs = [Document(text) for text in  list(set(ds["context"]))]
print(len(all_docs))
# Out:
# 1204

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(all_docs)

print(f"Split wiki abstract into {len(all_splits)} sub-documents.")
# Out:
# Split wiki abstract into 1222 sub-documents.

# %% [markdown]
# ## TODO 1: Hybrid Search
# Embed your documents in a vector database that supports hybrid search. Also set the retrieval mode to hybrid search. Use BM25 as the lexical search.
#
# Hint: read more on `QdrantVectorStore` [here](https://python.langchain.com/api_reference/qdrant/qdrant/langchain_qdrant.qdrant.QdrantVectorStore.html#langchain_qdrant.qdrant.QdrantVectorStore). (You can use any vector DB that can do hybrid search)

# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

client = QdrantClient(":memory:")

client.create_collection(
    collection_name="demo_collection",
    vectors_config=VectorParams(size=768, distance=Distance.COSINE),
)

vector_store = QdrantVectorStore(
    client=client,
    collection_name="demo_collection",
    embedding=embeddings,
)

vector_store.add_documents(all_splits)
# Out:
# W0406 11:48:53.843000 1672 torch/_inductor/utils.py:1137] [1/0] Not enough SMs to use max_autotune_gemm mode
# ['ef58023d0e0b461fb269e5af612651d9',
#  '3da3d6cd1b0647f4a66b7af1bad79206',
#  'a7b7ef09c3f14c19a5e33672d23054e6',
#  '7e380bf748594e84ba76ad2be0f2310a',
#  'c1682d1bea5047df9ad2867713a91edf',
#  'e1b596502bcd43d7ac0a9a0d752c1688',
#  '5d91d7c0f6014df38060bf21f6946408',
#  'd4bcc86e0e074d7497db5145155e9043',
#  '1616b558f0c54c8795ebf1cb2cf71b40',
#  '205258bd5dd949de93f8ee2cc77576ab',
#  '233783719e474d10a3568c0c41ce6312',
#  '94ce852b21cb4f02ae5702036155a9d9',
#  'a5046a5ea6b8459c95837f7f109efbca',
#  '7ddeb6b36dc84fb79322b6e4cb805e03',
#  '0874a1411b3947dfa30348afc5e96fe0',
#  '0fadbc4eb2be4e87a13b9930a391a103',
#  '7dea7efc4b37449f9f0a136c2e310b08',
#  '3d4fbfcabc1741e098fadf96885c7a2e',
#  'dac12529ddb044279ef2fbf3939ef55f',
#  'dba3961bfb2243dd8b356c440cdfe32f',
#  '1cb69f35b3b549e6bb6bf04d28674b38',
#  '68114e78cec34d2982910b6e10e551be',
#  '83bba2c0c4614ab2ac10068fc684b9d7',
#  '81f04274bbb94fd5bc9d26fd2565f2d2',
#  'a48dc314808f403fa231f276cb40cbe1',
#  '23b483b4950e4ac697ad865a26c295c2',
#  'b1669bfd5ecf4788b0fc2a8407d0cfb0',
#  '359a3049b7ab4e18aeb64640849fe235',
#  '95afb10c91a54ce499f74df474d53e52',
#  'bc42417b3b174acb96447a54e7a39676',
#  'e0a6023aac964312b861ea41b4b6fc82',
#  '688a1405c0f649de97971a53688ed2f6',
#  '1b7fface52904935b5db74b7024599dd',
#  'c173e1e880e24237be81806ed59f103f',
#  'bfe54a88960947d8b146cd05cee56730',
#  '1e12c2622c504d34a921d2d56da7e8a0',
#  'c231b4e87c0a49838fd9ea12064b5ca5',
#  '3a5e8df08d9349fda43a6275b1297b48',
#  'd24724a5287447e0b3dcee4787ef032b',
#  '1a284249d3734c3693c785e2f60759aa',
#  'ea2160af04a543e69a7ecf776efcb98b',
#  '61b3f5c254ca42ca94804f07317c4c34',
#  '84c213cea425438593f383655e498001',
#  'bf99aee3280b45cca652d56e3ff2a5b8',
#  '8683287a35ce47ca8db95d7c023f0006',
#  'f10c3583ebc5425091fea9eb16e2558c',
#  '51f36b904bff405c9027cd1e2a7fec53',
#  '2fbfbdefd1f24bcfba66b1e50d460ad1',
#  'b70b32b91809431e8df69742ba939c2c',
#  '249353f374d641c7b75d288d6158fc6e',
#  '41169455f7234cf7832c74970f19f384',
#  'ab8d3b2370cf4afc8f564cc9a6938637',
#  '16a69dd9b2584e018dfa6b7c5fb52a3e',
#  '9b5edd6c48174ddfa339486d8d358930',
#  'bd4fa5173e4c47d68f0b6ff6af65185e',
#  '86c291a5538c4d85a81f454b62215c67',
#  '26e1d83b7da44c3da86c3ef2445f5c9c',
#  '88b39a52c9b94f1daed2634bd9c2e0ea',
#  'dd9e1145cd224c6ca19122bea4f258a1',
#  '4ca1149bd7e146159fc5841342253950',
#  '789e5bdab1b643e59bc18c3ecd6b07c4',
#  'e6966329e8b14325858d2535fd445fd6',
#  '32d4ee58fb3e4ca7b6e6fe4c39866323',
#  '64224fc5fda94dbcb4d191fde8c1e2bc',
#  'bd18eaa8341544b781a75c78f6df31c2',
#  '46b51c61ae5947419ebfe37951f87d78',
#  '4ae23814223544779c2dbd1bf1ffb37e',
#  ...]

# %% [markdown]
# ## TODO 2: Reranking
#
# Create two retrievers.
# 1. A normal retriever without a reranker. Set the `top_k` to 20.
# 2. A retriever with a reranker. Set the `top_k` of the reranker to 3.

# %%
retriever_normal = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 20},
)

retriever_mmr = vector_store.as_retriever(
    search_type="mmr",
    search_kwargs={"k": 20, "fetch_k": 20, "lambda_mult": 0.5},
)

reranker = CrossEncoderReranker(model=model)
def reranked_retriever(query):
    retrieved_docs = retriever_mmr.invoke(query)

    reranked_docs = reranker.compress_documents(retrieved_docs, query=query)[:3]

    return reranked_docs

# %% [markdown]
# Take a subset of the dataset to evaluate the MRR of the retrievers.

# %%
sample = ds.take(1000)
print(sample)
# Out:
# Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 1000
# })

# %% [markdown]
# ## TODO 3: Retrieval Evaluation
#
# Calculate the MRR of the two retrievers based on the top 3 returned by each retriever.
#
# **For the vanilla retriever (no reranker), take only the top-3 to evaluate the MRR and ignore the rest.**

# %%
from tqdm import tqdm

no_rerank = no_rerank_failures = 0
limit = -1
count = 0

for row in tqdm(sample):
    query = row["question"]
    context = row["context"]

    res_mmr = retriever_mmr.invoke(query)
    found = False
    for i in range(3):
        doc_content = res_mmr[i].page_content
        if doc_content == context:
            no_rerank += 1/(i+1)
            found = True
            break
    if not found:
        print(f"Query {count}: Failed to find relevant doc in top 3 results")
        no_rerank_failures += 1

    count += 1
    if limit != -1 and count == limit:
        break

rerank = rerank_failures = 0
index = 0
limit = -1

for index in tqdm(range(len(sample))):
    row = sample[index]
    query = row["question"]
    context = row["context"]

    res_reranked = reranked_retriever(query)
    found = False
    for i in range(3):
        doc_content = res_reranked[i].page_content
        if doc_content == context:
            rerank += 1/(i+1)
            found = True
            break
    if not found:
        print(f"Query {index}: Failed to find relevant doc in top 3 results")
        rerank_failures += 1

    index += 1
    if limit != -1 and index == limit:
        break
# Out:
#   0%|          | 3/1000 [00:00<02:14,  7.39it/s]WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=1bb482cf-79bc-490c-baa6-88dd4bd315b6,id=1bb482cf-79bc-490c-baa6-88dd4bd315b6; trace=3cdb61ad-cebc-4f3c-9d85-d77a3b3d6905,id=3cdb61ad-cebc-4f3c-9d85-d77a3b3d6905
#   0%|          | 4/1000 [00:00<02:09,  7.68it/s]
# Query 2: Failed to find relevant doc in top 3 results
#   1%|          | 8/1000 [00:01<01:56,  8.54it/s]
# Query 6: Failed to find relevant doc in top 3 results
# Query 7: Failed to find relevant doc in top 3 results
#   1%|          | 10/1000 [00:01<02:01,  8.18it/s]
# Query 8: Failed to find relevant doc in top 3 results
# Query 9: Failed to find relevant doc in top 3 results
#   1%|          | 12/1000 [00:01<01:58,  8.36it/s]
# Query 10: Failed to find relevant doc in top 3 results
# Query 11: Failed to find relevant doc in top 3 results
#   2%|▏         | 16/1000 [00:01<01:58,  8.33it/s]
# Query 14: Failed to find relevant doc in top 3 results
# Query 15: Failed to find relevant doc in top 3 results
#   2%|▏         | 17/1000 [00:02<02:14,  7.33it/s]
# Query 16: Failed to find relevant doc in top 3 results
#   3%|▎         | 26/1000 [00:03<02:56,  5.53it/s]
# Query 24: Failed to find relevant doc in top 3 results
#   3%|▎         | 29/1000 [00:04<02:47,  5.81it/s]
# Query 27: Failed to find relevant doc in top 3 results
#   3%|▎         | 33/1000 [00:04<02:16,  7.07it/s]
# Query 31: Failed to find relevant doc in top 3 results
# Query 32: Failed to find relevant doc in top 3 results
#   5%|▌         | 52/1000 [00:07<01:52,  8.46it/s]
# Query 50: Failed to find relevant doc in top 3 results
#   5%|▌         | 53/1000 [00:07<01:51,  8.51it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▌         | 54/1000 [00:07<01:53,  8.35it/s]
# Query 52: Failed to find relevant doc in top 3 results
#   6%|▌         | 58/1000 [00:07<01:49,  8.60it/s]
# Query 56: Failed to find relevant doc in top 3 results
#   6%|▋         | 63/1000 [00:08<01:54,  8.18it/s]
# Query 61: Failed to find relevant doc in top 3 results
#   6%|▋         | 65/1000 [00:08<01:56,  8.06it/s]
# Query 63: Failed to find relevant doc in top 3 results
# Query 64: Failed to find relevant doc in top 3 results
#   7%|▋         | 68/1000 [00:09<01:49,  8.54it/s]
# Query 66: Failed to find relevant doc in top 3 results
#   7%|▋         | 71/1000 [00:09<01:48,  8.56it/s]
# Query 69: Failed to find relevant doc in top 3 results
#   7%|▋         | 73/1000 [00:09<01:48,  8.57it/s]
# Query 71: Failed to find relevant doc in top 3 results
# Query 72: Failed to find relevant doc in top 3 results
#   8%|▊         | 76/1000 [00:10<01:46,  8.71it/s]
# Query 74: Failed to find relevant doc in top 3 results
# Query 75: Failed to find relevant doc in top 3 results
#   8%|▊         | 79/1000 [00:10<01:46,  8.62it/s]
# Query 77: Failed to find relevant doc in top 3 results
#   8%|▊         | 82/1000 [00:10<01:49,  8.37it/s]
# Query 80: Failed to find relevant doc in top 3 results
#  10%|█         | 100/1000 [00:12<01:48,  8.31it/s]
# Query 98: Failed to find relevant doc in top 3 results
#  10%|█         | 102/1000 [00:13<01:46,  8.45it/s]
# Query 100: Failed to find relevant doc in top 3 results
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  10%|█         | 104/1000 [00:13<01:45,  8.48it/s]
# Query 102: Failed to find relevant doc in top 3 results
#  11%|█         | 106/1000 [00:13<01:43,  8.66it/s]
# Query 104: Failed to find relevant doc in top 3 results
#  11%|█         | 112/1000 [00:14<01:42,  8.67it/s]
# Query 110: Failed to find relevant doc in top 3 results
#  12%|█▏        | 115/1000 [00:14<01:44,  8.45it/s]
# Query 113: Failed to find relevant doc in top 3 results
#  13%|█▎        | 130/1000 [00:17<02:10,  6.68it/s]
# Query 128: Failed to find relevant doc in top 3 results
#  13%|█▎        | 132/1000 [00:17<01:56,  7.43it/s]
# Query 130: Failed to find relevant doc in top 3 results
# Query 131: Failed to find relevant doc in top 3 results
#  14%|█▍        | 139/1000 [00:18<01:44,  8.24it/s]
# Query 137: Failed to find relevant doc in top 3 results
#  15%|█▍        | 148/1000 [00:19<01:47,  7.92it/s]
# Query 146: Failed to find relevant doc in top 3 results
# Query 147: Failed to find relevant doc in top 3 results
#  15%|█▌        | 152/1000 [00:19<01:43,  8.19it/s]
# Query 150: Failed to find relevant doc in top 3 results
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  16%|█▌        | 158/1000 [00:20<01:39,  8.48it/s]
# Query 156: Failed to find relevant doc in top 3 results
#  16%|█▋        | 163/1000 [00:21<01:37,  8.59it/s]
# Query 161: Failed to find relevant doc in top 3 results
#  16%|█▋        | 165/1000 [00:21<01:37,  8.53it/s]
# Query 163: Failed to find relevant doc in top 3 results
# Query 164: Failed to find relevant doc in top 3 results
#  17%|█▋        | 172/1000 [00:22<01:43,  8.02it/s]
# Query 170: Failed to find relevant doc in top 3 results
# Query 171: Failed to find relevant doc in top 3 results
#  18%|█▊        | 176/1000 [00:22<01:35,  8.59it/s]
# Query 174: Failed to find relevant doc in top 3 results
#  19%|█▊        | 187/1000 [00:24<01:34,  8.58it/s]
# Query 185: Failed to find relevant doc in top 3 results
#  19%|█▉        | 190/1000 [00:24<01:37,  8.35it/s]
# Query 188: Failed to find relevant doc in top 3 results
# Query 189: Failed to find relevant doc in top 3 results
#  20%|█▉        | 199/1000 [00:25<01:36,  8.28it/s]
# Query 197: Failed to find relevant doc in top 3 results
#  20%|██        | 202/1000 [00:25<01:36,  8.26it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  20%|██        | 203/1000 [00:26<01:36,  8.28it/s]
# Query 201: Failed to find relevant doc in top 3 results
# Query 202: Failed to find relevant doc in top 3 results
#  21%|██        | 209/1000 [00:26<01:31,  8.62it/s]
# Query 207: Failed to find relevant doc in top 3 results
#  22%|██▏       | 215/1000 [00:27<02:06,  6.21it/s]
# Query 213: Failed to find relevant doc in top 3 results
# Query 214: Failed to find relevant doc in top 3 results
#  22%|██▏       | 217/1000 [00:28<02:17,  5.71it/s]
# Query 215: Failed to find relevant doc in top 3 results
#  22%|██▏       | 220/1000 [00:28<02:25,  5.34it/s]
# Query 218: Failed to find relevant doc in top 3 results
#  22%|██▏       | 224/1000 [00:29<02:20,  5.53it/s]
# Query 223: Failed to find relevant doc in top 3 results
#  23%|██▎       | 227/1000 [00:29<01:57,  6.58it/s]
# Query 225: Failed to find relevant doc in top 3 results
# Query 226: Failed to find relevant doc in top 3 results
#  23%|██▎       | 232/1000 [00:30<01:35,  8.08it/s]
# Query 230: Failed to find relevant doc in top 3 results
#  25%|██▍       | 246/1000 [00:31<01:28,  8.50it/s]
# Query 244: Failed to find relevant doc in top 3 results
#  25%|██▍       | 249/1000 [00:32<01:28,  8.51it/s]
# Query 247: Failed to find relevant doc in top 3 results
#  25%|██▌       | 251/1000 [00:32<01:29,  8.33it/s]
# Query 249: Failed to find relevant doc in top 3 results
#  25%|██▌       | 252/1000 [00:32<01:30,  8.25it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  25%|██▌       | 253/1000 [00:32<01:30,  8.30it/s]
# Query 251: Failed to find relevant doc in top 3 results
#  26%|██▌       | 261/1000 [00:33<01:26,  8.50it/s]
# Query 259: Failed to find relevant doc in top 3 results
#  26%|██▋       | 263/1000 [00:33<01:25,  8.61it/s]
# Query 261: Failed to find relevant doc in top 3 results
# Query 262: Failed to find relevant doc in top 3 results
#  27%|██▋       | 268/1000 [00:34<01:26,  8.48it/s]
# Query 266: Failed to find relevant doc in top 3 results
# Query 267: Failed to find relevant doc in top 3 results
#  27%|██▋       | 273/1000 [00:35<01:24,  8.61it/s]
# Query 271: Failed to find relevant doc in top 3 results
#  29%|██▊       | 286/1000 [00:36<01:28,  8.03it/s]
# Query 284: Failed to find relevant doc in top 3 results
# Query 285: Failed to find relevant doc in top 3 results
#  29%|██▉       | 290/1000 [00:37<01:24,  8.40it/s]
# Query 288: Failed to find relevant doc in top 3 results
#  30%|██▉       | 296/1000 [00:37<01:24,  8.30it/s]
# Query 294: Failed to find relevant doc in top 3 results
# Query 295: Failed to find relevant doc in top 3 results
#  30%|██▉       | 298/1000 [00:38<01:22,  8.52it/s]
# Query 296: Failed to find relevant doc in top 3 results
#  30%|███       | 301/1000 [00:38<01:21,  8.61it/s]
# Query 299: Failed to find relevant doc in top 3 results
# Query 300: Failed to find relevant doc in top 3 results
#  30%|███       | 302/1000 [00:38<01:22,  8.47it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  30%|███       | 303/1000 [00:38<01:23,  8.36it/s]
# Query 301: Failed to find relevant doc in top 3 results
#  30%|███       | 305/1000 [00:38<01:21,  8.52it/s]
# Query 303: Failed to find relevant doc in top 3 results
# Query 304: Failed to find relevant doc in top 3 results
#  31%|███       | 309/1000 [00:39<01:19,  8.64it/s]
# Query 307: Failed to find relevant doc in top 3 results
#  31%|███       | 312/1000 [00:39<01:37,  7.03it/s]
# Query 310: Failed to find relevant doc in top 3 results
#  31%|███▏      | 314/1000 [00:40<01:56,  5.87it/s]
# Query 312: Failed to find relevant doc in top 3 results
# Query 313: Failed to find relevant doc in top 3 results
#  32%|███▏      | 320/1000 [00:41<01:56,  5.85it/s]
# Query 319: Failed to find relevant doc in top 3 results
#  32%|███▏      | 322/1000 [00:41<02:04,  5.43it/s]
# Query 320: Failed to find relevant doc in top 3 results
# Query 321: Failed to find relevant doc in top 3 results
#  32%|███▏      | 324/1000 [00:42<02:02,  5.51it/s]
# Query 322: Failed to find relevant doc in top 3 results
# Query 323: Failed to find relevant doc in top 3 results
#  33%|███▎      | 330/1000 [00:42<01:25,  7.84it/s]
# Query 328: Failed to find relevant doc in top 3 results
# Query 329: Failed to find relevant doc in top 3 results
#  33%|███▎      | 332/1000 [00:43<01:25,  7.86it/s]
# Query 330: Failed to find relevant doc in top 3 results
# Query 331: Failed to find relevant doc in top 3 results
#  33%|███▎      | 334/1000 [00:43<01:22,  8.08it/s]
# Query 332: Failed to find relevant doc in top 3 results
#  35%|███▌      | 352/1000 [00:45<01:19,  8.18it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  35%|███▌      | 353/1000 [00:45<01:19,  8.18it/s]
# Query 351: Failed to find relevant doc in top 3 results
#  36%|███▌      | 355/1000 [00:45<01:16,  8.40it/s]
# Query 353: Failed to find relevant doc in top 3 results
#  36%|███▌      | 359/1000 [00:46<01:16,  8.33it/s]
# Query 357: Failed to find relevant doc in top 3 results
#  36%|███▌      | 361/1000 [00:46<01:15,  8.43it/s]
# Query 359: Failed to find relevant doc in top 3 results
#  36%|███▋      | 363/1000 [00:46<01:14,  8.53it/s]
# Query 361: Failed to find relevant doc in top 3 results
#  36%|███▋      | 365/1000 [00:47<01:14,  8.49it/s]
# Query 363: Failed to find relevant doc in top 3 results
#  37%|███▋      | 372/1000 [00:47<01:11,  8.79it/s]
# Query 370: Failed to find relevant doc in top 3 results
#  38%|███▊      | 379/1000 [00:48<01:12,  8.54it/s]
# Query 377: Failed to find relevant doc in top 3 results
#  38%|███▊      | 382/1000 [00:49<01:12,  8.47it/s]
# Query 380: Failed to find relevant doc in top 3 results
# Query 381: Failed to find relevant doc in top 3 results
#  38%|███▊      | 384/1000 [00:49<01:13,  8.37it/s]
# Query 382: Failed to find relevant doc in top 3 results
#  39%|███▉      | 391/1000 [00:50<01:11,  8.46it/s]
# Query 389: Failed to find relevant doc in top 3 results
#  39%|███▉      | 394/1000 [00:50<01:12,  8.35it/s]
# Query 392: Failed to find relevant doc in top 3 results
#  40%|███▉      | 399/1000 [00:51<01:10,  8.53it/s]
# Query 397: Failed to find relevant doc in top 3 results
# Query 398: Failed to find relevant doc in top 3 results
#  40%|████      | 402/1000 [00:51<01:11,  8.41it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#
/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  85%|████████▌ | 853/1000 [01:49<00:18,  8.08it/s]
# Query 851: Failed to find relevant doc in top 3 results
#  86%|████████▌ | 856/1000 [01:50<00:17,  8.23it/s]
# Query 854: Failed to find relevant doc in top 3 results
#  86%|████████▌ | 858/1000 [01:50<00:17,  8.30it/s]
# Query 856: Failed to find relevant doc in top 3 results
# Query 857: Failed to find relevant doc in top 3 results
#  88%|████████▊ | 884/1000 [01:53<00:13,  8.49it/s]
# Query 882: Failed to find relevant doc in top 3 results
#  90%|█████████ | 902/1000 [01:55<00:13,  7.02it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  91%|█████████ | 907/1000 [01:56<00:16,  5.68it/s]
# Query 905: Failed to find relevant doc in top 3 results
#  91%|█████████ | 911/1000 [01:57<00:15,  5.82it/s]
# Query 909: Failed to find relevant doc in top 3 results
#  93%|█████████▎| 932/1000 [02:00<00:08,  8.17it/s]
# Query 930: Failed to find relevant doc in top 3 results
#  94%|█████████▍| 943/1000 [02:01<00:06,  8.38it/s]
# Query 941: Failed to find relevant doc in top 3 results
# Query 942: Failed to find relevant doc in top 3 results
#  94%|█████████▍| 945/1000 [02:01<00:06,  8.41it/s]
# Query 943: Failed to find relevant doc in top 3 results
#  95%|█████████▌| 952/1000 [02:02<00:05,  8.31it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  95%|█████████▌| 953/1000 [02:02<00:05,  8.35it/s]
# Query 951: Failed to find relevant doc in top 3 results
#  96%|█████████▌| 956/1000 [02:03<00:05,  8.56it/s]
# Query 954: Failed to find relevant doc in top 3 results
#  96%|█████████▌| 958/1000 [02:03<00:05,  8.37it/s]
# Query 956: Failed to find relevant doc in top 3 results
#  97%|█████████▋| 968/1000 [02:04<00:03,  8.44it/s]
# Query 966: Failed to find relevant doc in top 3 results
#  97%|█████████▋| 970/1000 [02:04<00:03,  8.45it/s]
# Query 968: Failed to find relevant doc in top 3 results
#  98%|█████████▊| 980/1000 [02:05<00:02,  8.45it/s]
# Query 978: Failed to find relevant doc in top 3 results
# Query 979: Failed to find relevant doc in top 3 results
#  99%|█████████▊| 986/1000 [02:06<00:01,  8.58it/s]
# Query 984: Failed to find relevant doc in top 3 results
# 100%|██████████| 1000/1000 [02:08<00:00,  7.79it/s]
#   0%|          | 1/1000 [00:00<12:50,  1.30it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   0%|          | 4/1000 [00:02<11:21,  1.46it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   0%|          | 5/1000 [00:03<11:21,  1.46it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   1%|          | 10/1000 [00:06<10:01,  1.65it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   1%|          | 12/1000 [00:07<10:21,  1.59it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   2%|▏         | 16/1000 [00:09<09:26,  1.74it/s]
# Query 15: Failed to find relevant doc in top 3 results
#   2%|▏         | 19/1000 [00:11<09:45,  1.68it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   2%|▏         | 23/1000 [00:14<10:54,  1.49it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   3%|▎         | 26/1000 [00:15<10:02,  1.62it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   3%|▎         | 28/1000 [00:17<10:16,  1.58it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   3%|▎         | 30/1000 [00:18<10:19,  1.56it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   3%|▎         | 31/1000 [00:19<10:52,  1.48it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   4%|▍         | 41/1000 [00:24<10:06,  1.58it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   4%|▍         | 42/1000 [00:25<10:42,  1.49it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   4%|▍         | 43/1000 [00:26<11:11,  1.42it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   4%|▍         | 44/1000 [00:27<11:09,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   4%|▍         | 45/1000 [00:27<11:33,  1.38it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▍         | 46/1000 [00:28<11:28,  1.38it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▍         | 47/1000 [00:29<11:29,  1.38it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▍         | 49/1000 [00:30<10:41,  1.48it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▌         | 50/1000 [00:31<10:53,  1.45it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▌         | 51/1000 [00:31<11:02,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▌         | 52/1000 [00:32<10:39,  1.48it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   5%|▌         | 54/1000 [00:33<10:35,  1.49it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▌         | 55/1000 [00:34<10:46,  1.46it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▌         | 56/1000 [00:35<11:00,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▌         | 57/1000 [00:36<10:43,  1.47it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▌         | 58/1000 [00:36<10:57,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▌         | 59/1000 [00:37<11:29,  1.36it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▌         | 62/1000 [00:39<10:34,  1.48it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# Query 61: Failed to find relevant doc in top 3 results
#   6%|▋         | 63/1000 [00:40<10:55,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▋         | 64/1000 [00:40<10:58,  1.42it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   6%|▋         | 65/1000 [00:41<10:59,  1.42it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 66/1000 [00:42<11:05,  1.40it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 67/1000 [00:43<11:16,  1.38it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 68/1000 [00:43<11:22,  1.37it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 69/1000 [00:44<11:17,  1.37it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 70/1000 [00:45<10:01,  1.55it/s]
# Query 69: Failed to find relevant doc in top 3 results
#   7%|▋         | 71/1000 [00:45<10:31,  1.47it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 72/1000 [00:46<10:51,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   7%|▋         | 74/1000 [00:47<10:21,  1.49it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#   8%|▊         | 75/1000 [00:48<10:52,  1.42it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# ...
#  84%|████████▍ | 841/1000 [08:10<01:47,  1.48it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# Query 840: Failed to find relevant doc in top 3 results
#  84%|████████▍ | 845/1000 [08:12<01:30,  1.72it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  85%|████████▍ | 847/1000 [08:13<01:33,  1.64it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  85%|████████▌ | 850/1000 [08:15<01:23,  1.79it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  85%|████████▌ | 852/1000 [08:16<01:22,  1.80it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  85%|████████▌ | 853/1000 [08:17<01:17,  1.89it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  86%|████████▌ | 858/1000 [08:20<01:28,  1.61it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# Query 857: Failed to find relevant doc in top 3 results
#  86%|████████▌ | 859/1000 [08:20<01:28,  1.60it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  86%|████████▌ | 862/1000 [08:22<01:28,  1.57it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  86%|████████▋ | 864/1000 [08:23<01:22,  1.64it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  87%|████████▋ | 866/1000 [08:25<01:21,  1.64it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  87%|████████▋ | 868/1000 [08:26<01:22,  1.59it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  87%|████████▋ | 871/1000 [08:28<01:17,  1.67it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  87%|████████▋ | 872/1000 [08:28<01:22,  1.56it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  88%|████████▊ | 879/1000 [08:32<01:16,  1.58it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  88%|████████▊ | 883/1000 [08:35<01:17,  1.51it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  89%|████████▉ | 891/1000 [08:40<01:07,  1.61it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  89%|████████▉ | 894/1000 [08:42<01:09,  1.53it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  90%|█████████ | 902/1000 [08:46<00:55,  1.76it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  91%|█████████ | 910/1000 [08:50<00:51,  1.74it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  91%|█████████ | 912/1000 [08:51<00:52,  1.68it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  92%|█████████▏| 918/1000 [08:54<00:44,  1.85it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  93%|█████████▎| 930/1000 [09:01<00:42,  1.64it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  93%|█████████▎| 931/1000 [09:02<00:39,  1.76it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  93%|█████████▎| 934/1000 [09:04<00:43,  1.53it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  94%|█████████▎| 937/1000 [09:06<00:39,  1.60it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  94%|█████████▍| 940/1000 [09:07<00:35,  1.70it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  94%|█████████▍| 943/1000 [09:09<00:32,  1.74it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  94%|█████████▍| 944/1000 [09:10<00:35,  1.60it/s]
# Query 943: Failed to find relevant doc in top 3 results
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  95%|█████████▍| 946/1000 [09:11<00:37,  1.43it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  96%|█████████▌| 961/1000 [09:19<00:22,  1.71it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  96%|█████████▋| 965/1000 [09:22<00:21,  1.61it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  97%|█████████▋| 966/1000 [09:22<00:23,  1.44it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
#  99%|█████████▉| 991/1000 [09:36<00:05,  1.60it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# 100%|█████████▉| 997/1000 [09:39<00:01,  1.84it/s]WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# 100%|██████████| 1000/1000 [09:40<00:00,  1.72it/s]

# %%
print(f"MRR of the retriever without a reranker: {no_rerank / len(sample):.4f}")
print(f"MRR of the retriever with a reranker: {rerank / len(sample):.4f}")

print(f"Percentage of queries with no relevant doc in top 3 (no rerank): {100 * no_rerank_failures / len(sample):.2f}%")
print(f"Percentage of queries with no relevant doc in top 3 (rerank): {100 * rerank_failures / len(sample):.2f}%")
# Out:
# MRR of the retriever without a reranker: 0.7510
# MRR of the retriever with a reranker: 0.9237
# Percentage of queries with no relevant doc in top 3 (no rerank): 21.90%
# Percentage of queries with no relevant doc in top 3 (rerank): 4.50%

# %% [markdown]
# ## Agentic RAG
#
# Feel free to use the workflow from the demo. However, you will need to modify it slightly to use the retriever with a reranker.

# %% [markdown]
# ## TODO 4: Usage
# Run your agent twice. Once on a message that doesn't need tool-use like "hello" and again for a message that does.

# %%
from langgraph.graph import MessagesState, StateGraph
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage
from langgraph.prebuilt import ToolNode
from langsmith import traceable

graph_builder = StateGraph(MessagesState)

@tool(response_format="content_and_artifact")
def retrieve(query: str):
    """Retrieve information related to a query from a vector database containing information on various topics from Wikipedia"""
    retrieved_docs = reranked_retriever(query)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\n" f"Content: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs



@traceable
def query_or_respond(state: MessagesState):
    """Generate tool call for retrieval or respond."""
    llm_with_tools = llm.bind_tools([retrieve])
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": [response]}

tools = ToolNode([retrieve])

@traceable
def generate(state: MessagesState):
    """Generate answer."""
    recent_tool_messages = []
    for message in reversed(state["messages"]):
        if message.type == "tool":
            recent_tool_messages.append(message)
        else:
            break
    tool_messages = recent_tool_messages[::-1]

    # Format into prompt
    docs_content = "\n\n".join(doc.content for doc in tool_messages)
    system_message_content = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer "
        "the question. If you don't know the answer, say that you "
        "don't know. Use three sentences maximum and keep the "
        "answer concise."
        "\n\n"
        f"{docs_content}"
    )
    conversation_messages = [
        message
        for message in state["messages"]
        if message.type in ("human", "system")
        or (message.type == "ai" and not message.tool_calls)
    ]
    prompt = [SystemMessage(system_message_content)] + conversation_messages

    response = llm.invoke(prompt)
    return {"messages": [response]}

# %%
from langgraph.graph import END
from langgraph.prebuilt import ToolNode, tools_condition
from IPython.display import Image, display

graph_builder.add_node(query_or_respond)
graph_builder.add_node(tools)
graph_builder.add_node(generate)

graph_builder.set_entry_point("query_or_respond")
graph_builder.add_conditional_edges(
    "query_or_respond",
    tools_condition,
    {END: END, "tools": "tools"},
)
graph_builder.add_edge("tools", "generate")
graph_builder.add_edge("generate", END)

graph = graph_builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)

config = {"configurable": {"thread_id": "abc123"}}

# %%
input_message = "hello"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# hello
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# ================================== Ai Message ==================================
#
# Hello! How can I help you today?

# %%
input_message = "What caused free movement of goods in the EU?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What caused free movement of goods in the EU?
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve (d98e38fe-1ee7-4932-811e-e614c452e8d8)
#  Call ID: d98e38fe-1ee7-4932-811e-e614c452e8d8
#   Args:
#     query: cause of free movement of goods in the EU
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# ================================= Tool Message =================================
# Name: retrieve
#
# Source: {'start_index': 0, '_id': '52563be979064f56889e7110c0d63b51', '_collection_name': 'demo_collection'}
# Content: Free movement of goods within the European Union is achieved by a customs union, and the principle of non-discrimination. The EU manages imports from non-member states, duties between member states are prohibited, and imports circulate freely. In addition under the Treaty on the Functioning of the European Union article 34, ‘Quantitative restrictions on imports and all measures having equivalent effect shall be prohibited between Member States’. In Procureur du Roi v Dassonville the Court of Justice held that this rule meant all "trading rules" that are "enacted by Member States" which could hinder trade "directly or indirectly, actually or potentially" would be caught by article 34. This meant that a Belgian law requiring Scotch whisky imports to have a certificate of origin was unlikely to be lawful. It discriminated against parallel importers like Mr Dassonville, who could not get certificates from authorities in France, where they bought the Scotch. This "wide test", to determine what could potentially be an unlawful restriction on trade, applies equally to actions by quasi-government bodies, such as the former "Buy Irish" company that had government appointees. It also means states can be responsible for private actors. For instance, in Commission v France French farmer vigilantes were continually sabotaging shipments of Spanish strawberries, and even Belgian tomato imports. France was liable for these hindrances to trade because the authorities ‘manifestly and persistently abstained' from preventing the sabotage. Generally speaking, if a member state has laws or practices that directly discriminate against imports (or exports under TFEU article 35) then it must be justified under article 36. The justifications include public morality, policy or security, "protection of health and life of humans, animals or plants", "national treasures" of "artistic, historic or archaeological value" and "industrial and commercial property." In addition, although not clearly
#
# Source: {'start_index': 0, '_id': 'ebdd0b75955b4bcd9ad2c90617759762', '_collection_name': 'demo_collection'}
# Content: While the concept of a "social market economy" was only introduced into EU law in 2007, free movement and trade were central to European development since the Treaty of Rome 1957. According to the standard theory of comparative advantage, two countries can both benefit from trade even if one of them has a less productive economy in all respects. Like in other regional organisations such as the North American Free Trade Association, or the World Trade Organisation, breaking down barriers to trade, and enhancing free movement of goods, services, labour and capital, is meant to reduce consumer prices. It was originally theorised that a free trade area had a tendency to give way to a customs union, which led to a common market, then monetary union, then union of monetary and fiscal policy, political and eventually a full union characteristic of a federal state. In Europe, however, those stages were considerably mixed, and it remains unclear whether the "endgame" should be the same as a state, traditionally understood. In practice free trade, without standards to ensure fair trade, can benefit some people and groups within countries (particularly big business) much more than others, but will burden people who lack bargaining power in an expanding market, particularly workers, consumers, small business, developing industries, and communities. The Treaty on the Functioning of the European Union articles 28 to 37 establish the principle of free movement of goods in the EU, while articles 45 to 66 require free movement of persons, services and capital. These so-called "four freedoms" were thought to be inhibited by physical barriers (e.g. customs), technical barriers (e.g. differing laws on safety, consumer or environmental standards) and fiscal barriers (e.g. different Value Added Tax rates). The tension in the law is that the free movement and trade is not supposed to spill over into a licence for unrestricted commercial profit. The Treaties limit free trade, to prioritise
#
# Source: {'start_index': 1803, '_id': 'ef9ac45a8cb34a66a5f29d2fae78df0b', '_collection_name': 'demo_collection'}
# Content: of health and life of humans, animals or plants", "national treasures" of "artistic, historic or archaeological value" and "industrial and commercial property." In addition, although not clearly listed, environmental protection can justify restrictions on trade as an overriding requirement derived from TFEU article 11. More generally, it has been increasingly acknowledged that fundamental human rights should take priority over all trade rules. So, in Schmidberger v Austria the Court of Justice held that Austria did not infringe article 34 by failing to ban a protest that blocked heavy traffic passing over the A13, Brenner Autobahn, en route to Italy. Although many companies, including Mr Schmidberger's German undertaking, were prevented from trading, the Court of Justice reasoned that freedom of association is one of the ‘fundamental pillars of a democratic society’, against which the free movement of goods had to be balanced, and was probably subordinate. If a member state does appeal to the article 36 justification, the measures it takes have to be applied proportionately. This means the rule must be pursue a legitimate aim and (1) be suitable to achieve the aim, (2) be necessary, so that a less restrictive measure could not achieve the same result, and (3) be reasonable in balancing the interests of free trade with interests in article 36.
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')
# ================================== Ai Message ==================================
#
# Free movement of goods within the EU is achieved by a customs union and the principle of non-discrimination. The Treaty on the Functioning of the European Union articles 28 to 37 establish the principle of free movement of goods in the EU. Breaking down barriers to trade and enhancing free movement of goods is meant to reduce consumer prices.

# %% [markdown]
# ## TODO 5: Monitor your agent in LangSmith.
#
# If you have set up correctly, you can just visit the LangSmith website and see that your tracings are logged into your LangSmith project.
#
# Capture your screen like this and upload it to MCV.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Result

# %% [markdown]
# ![image.png](data:image/png;base64,...)
